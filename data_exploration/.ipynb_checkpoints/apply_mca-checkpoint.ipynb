# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
from mca import MCA
import prince
from kmodes.kmodes import KModes
from sklearn.cluster import KMeans
from scipy import interpolate
from scipy.spatial import ConvexHull

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("../data/survey.csv")
df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#                 timestamp how_old_are_you                       industry  \
# 0      4/27/2021 11:02:10           25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22           25-34              Computing or Tech
# 2      4/27/2021 11:02:38           25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41           25-34                     Nonprofits
# 4      4/27/2021 11:02:42           25-34  Accounting, Banking & Finance
# ...                   ...             ...                            ...
# 26227  5/17/2021 17:42:33           25-34                Media & Digital
# 26228  5/17/2021 17:46:38           35-44                     Nonprofits
# 26229  5/17/2021 17:47:30           25-34              Computing or Tech
# 26230  5/17/2021 18:20:07           25-34    Marketing, Advertising & PR
# 26231  5/17/2021 19:48:52           35-44                            Law
#
#                                       job_title  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26232 entries, 0 to 26231
# Data columns (total 21 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   timestamp                                 26232 non-null  object
#  1   how_old_are_you                           26232 non-null  object
#  2   industry                                  26232 non-null  object
#  3   job_title                                 26232 non-null  object
#  4   additional_context_on_job_title           6763 non-null   object
#  5   annual_salary                             26232 non-null  int64
#  6   other_monetary_comp                       19447 non-null  float64
#  7   currency                                  26232 non-null  object
#  8   currency_other                            166 non-null    object
#  9   additional_context_on_income              2872 non-null   object
# ...

# %%
avg_wage = pd.read_csv("../data/avg_wage.csv", sep=";")
avg_wage
# Out:
#                       country  costs_idx  avg_annual_wage  avg_month_wage_  \
# 0                     Bermuda      167.5         108094.8             8189
# 1                 Switzerland      149.9          79569.6             6028
# 2              Cayman Islands      146.6          61630.8             4669
# 3                      Israel      132.4          41025.6             3108
# 4    Turks and Caicos Islands      132.4          29726.4             2252
# ..                        ...        ...              ...              ...
# 111                Kyrgyzstan       27.5           1122.0               85
# 112                Tajikistan       26.7           1016.4               77
# 113                  Pakistan       26.4           1227.6               93
# 114                    Angola       26.3           2059.2              156
# 115               Afghanistan       23.7            475.2               36
#
#      purchasing_power_idx
# 0                   169.8
# ...

# %%
pd.merge(df, avg_wage, left_on="country", right_on="country", how="inner")["country"].nunique()
# Out:
# 63

# %%
sub_df = sub_df = df[(df["annual_salary"] < 1000000) & (df["annual_salary"] > 10000)][
    [
        "annual_salary",
        "how_old_are_you",
        "overall_years_of_professional_experience",
        "years_of_experience_in_field",
        "highest_level_of_education_completed",
        "gender",
        "industry cluster tf_idf_bigrams", 
        "country"
    ]
]

# %%
sub_df
# Out:
#        annual_salary how_old_are_you overall_years_of_professional_experience  \
# 0              55000           25-34                                5-7 years
# 1              54600           25-34                             8 - 10 years
# 2              34000           25-34                              2 - 4 years
# 3              62000           25-34                             8 - 10 years
# 4              60000           25-34                             8 - 10 years
# ...              ...             ...                                      ...
# 26227          85000           25-34                                5-7 years
# 26228          40000           35-44                            11 - 20 years
# 26229         148000           25-34                            11 - 20 years
# 26230          65000           25-34                              2 - 4 years
# 26231         146192           35-44                            11 - 20 years
#
# ...

# %%
sub_df.dropna(inplace=True)

# %%
sub_df["overall_years_of_professional_experience"].unique()
# Out:
# array(['5-7 years', '8 - 10 years', '2 - 4 years', '21 - 30 years',
#        '11 - 20 years', '1 year or less', '41 years or more',
#        '31 - 40 years'], dtype=object)

# %%
sub_df["overall_years_of_professional_experience"] = pd.Categorical(
    sub_df["overall_years_of_professional_experience"],
    ordered=True,
    categories=[
        "1 year or less",
        "2 - 4 years",
        "5-7 years",
        "8 - 10 years",
        "11 - 20 years",
        "21 - 30 years",
        "31 - 40 years",
        "41 years or more"
    ]
)

# %%
sub_df["years_of_experience_in_field"].unique()
# Out:
# array(['5-7 years', '2 - 4 years', '21 - 30 years', '11 - 20 years',
#        '1 year or less', '8 - 10 years', '31 - 40 years',
#        '41 years or more'], dtype=object)

# %%
sub_df["years_of_experience_in_field"] = pd.Categorical(
    sub_df["years_of_experience_in_field"],
    ordered=True,
    categories=[
        "1 year or less",
        "2 - 4 years",
        "5-7 years",
        "8 - 10 years",
        "11 - 20 years",
        "21 - 30 years",
        "31 - 40 years",
        "41 years or more"
    ]
)

# %%
sub_df["highest_level_of_education_completed"].unique()
# Out:
# array(["Master's degree", 'College degree', 'PhD', 'Some college',
#        'High School', 'Professional degree (MD, JD, etc.)'], dtype=object)

# %%
sub_df["highest_level_of_education_completed"].fillna("None", inplace=True)

# %%
sub_df["highest_level_of_education_completed"] = pd.Categorical(
    sub_df["highest_level_of_education_completed"],
    ordered=False,
    categories=[
        "High School",
        "Some college",
        "College degree",
        "Master's degree",
        "PhD",
        "Professional degree (MD, JD, etc.)"
    ]
)

# %%
sub_df["highest_level_of_education_completed"].unique()
# Out:
# ['Master's degree', 'College degree', 'PhD', 'Some college', 'High School', 'Professional degree (MD, JD, etc.)']
# Categories (6, object): ['High School', 'Some college', 'College degree', 'Master's degree', 'PhD', 'Professional degree (MD, JD, etc.)']

# %%
sub_df["gender"] = pd.Categorical(
    sub_df["gender"],
    categories=[
        "Man",
        "Woman",
        "Non-binary",
        "Prefer not to answer"
    ]
)

# %%
sub_df["industry cluster tf_idf_bigrams"] = pd.Categorical(
    sub_df["industry cluster tf_idf_bigrams"]
)

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25863 entries, 0 to 26231
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   annual_salary                             25863 non-null  int64
#  1   how_old_are_you                           25863 non-null  object
#  2   overall_years_of_professional_experience  25863 non-null  category
#  3   years_of_experience_in_field              25863 non-null  category
#  4   highest_level_of_education_completed      25863 non-null  category
#  5   gender                                    25863 non-null  category
#  6   industry cluster tf_idf_bigrams           25863 non-null  category
#  7   country                                   25863 non-null  object
# dtypes: category(5), int64(1), object(2)
# memory usage: 936.3+ KB

# %%
sns.boxplot(data=sub_df, y="annual_salary")
# Out:
# <AxesSubplot:ylabel='annual_salary'>

# %%
def categorize_salary(x):
    if x <= sub_df["annual_salary"].quantile(0.25):
        return "low"
    if x <= sub_df["annual_salary"].quantile(0.5) and x >= sub_df["annual_salary"].quantile(0.25):
        return "medium low"
    if x <= sub_df["annual_salary"].quantile(0.75) and x >= sub_df["annual_salary"].quantile(0.5):
        return "medium high"
    if x >= sub_df["annual_salary"].quantile(0.75):
        return "high"

# %%
sub_df["category_salary"] = sub_df["annual_salary"].apply(categorize_salary)

# %%
sub_df["category_salary"] = pd.Categorical(
    sub_df["category_salary"],
    ordered=True,
    categories = [
        "high",
        "medium high",
        "medium low",
        "low"
    ]
)

# %%
sub_df["category_salary"].dtype
# Out:
# CategoricalDtype(categories=['high', 'medium high', 'medium low', 'low'], ordered=True)

# %% [markdown]
# # ACM on industry, gender and category salary

# %%
test = sub_df.drop(#sub_df[(sub_df["how_old_are_you"] != "under 18") & (sub_df["how_old_are_you"] != "under 18")].drop(
        [
            
            "annual_salary",
            #"industry cluster tf_idf_bigrams",
            #"gender",
            "overall_years_of_professional_experience",
            "years_of_experience_in_field", 
            "country",
            "highest_level_of_education_completed",
            #"category_salary",
            "how_old_are_you",
        ],
        axis=1
)

# %%
test
# Out:
#            gender industry cluster tf_idf_bigrams category_salary
# 0           Woman                       Education      medium low
# 1      Non-binary            Technology & Science             low
# 2           Woman             Banking & Insurance             low
# 3           Woman         Non profit Organization      medium low
# 4           Woman             Banking & Insurance      medium low
# ...           ...                             ...             ...
# 26227       Woman                    Unidentified     medium high
# 26228       Woman         Non profit Organization             low
# 26229       Woman            Technology & Science            high
# 26230       Woman                     Advertising      medium low
# 26231       Woman                             Law            high
#
# [25863 rows x 3 columns]

# %%
mca = prince.MCA(n_components=5, n_iter=1000, copy=True, check_input=True, engine='auto')
pls = mca.fit(test)
#pls["extreme"] = sub_df["extreme"]

# %%
pls["salary"] = sub_df["category_salary"]
pls["age"] = sub_df["how_old_are_you"]
pls["years"] = sub_df["years_of_experience_in_field"]
pls["education_completed"] = sub_df["highest_level_of_education_completed"]
pls["overall"] = sub_df["overall_years_of_professional_experience"]
pls["gender"] = sub_df["gender"]
pls["country"] = sub_df["country"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/13/2bs52tzx5vb8jg2f094msm5h0000gn/T/ipykernel_30973/772989613.py in <module>
# ----> 1 pls["salary"] = sub_df["category_salary"]
#       2 pls["age"] = sub_df["how_old_are_you"]
#       3 pls["years"] = sub_df["years_of_experience_in_field"]
#       4 pls["education_completed"] = sub_df["highest_level_of_education_completed"]
#       5 pls["overall"] = sub_df["overall_years_of_professional_experience"]
#
# TypeError: 'MCA' object does not support item assignment

# %%
g = sns.scatterplot(
    data=pls, x=0, y=1, 
    #hue="salary", style="age",
    hue="age", style="education_completed", size="salary",
    sizes=(100, 800),
)

g.set(xlabel = 'Axe 1', ylabel = 'Axe 2')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/13/2bs52tzx5vb8jg2f094msm5h0000gn/T/ipykernel_30973/4085428801.py in <module>
# ----> 1 g = sns.scatterplot(
#       2     data=pls, x=0, y=1,
#       3     #hue="salary", style="age",
#       4     hue="age", style="education_completed", size="salary",
#       5     sizes=(100, 800),
#
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
mca.explained_inertia_
# Out:
# [0.05987047240228464,
#  0.04452346234694681,
#  0.0409827253039362,
#  0.04032594345148177,
#  0.03950494751778461]

# %%
mca.plot_coordinates(
    X=test,
    ax=None,
    figsize=(12, 12),
    show_row_points=False,
    row_points_alpha=0.5,
    show_column_labels=True,
    show_column_points=True,
    show_row_labels=False,
    row_points_size=10,
    column_points_size=50,
    legend_n_cols=2,
)
# Out:
# <AxesSubplot:title={'center':'Row and column principal coordinates'}, xlabel='Component 0 (5.99% inertia)', ylabel='Component 1 (4.45% inertia)'>

# %%
def get_differenciation(x):
    if "gender_" in x:
        return "Gender"
    elif "industry cluster tf_idf_bigrams_" in x:
        return "Industry"
    elif "category_salary" in x:
        return "Salary Category"

# %%
transfo = mca.column_coordinates(test).reset_index()
transfo["color"] = transfo["index"].apply(get_differenciation)
transfo["index"] = transfo["index"].str.replace("gender_", "")
transfo["index"] = transfo["index"].str.replace("industry cluster tf_idf_bigrams_", "")
transfo["index"] = transfo["index"].str.replace("gender_", "")
transfo["index"] = transfo["index"].str.replace("category_salary_", "")

# %%
plt.figure(figsize=(10, 10))
ax = sns.scatterplot(data=transfo, x=0, y=1, hue="color", s=200, style="color")

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[0], transfo[1], transfo["index"], plt.gca())  
plt.show()

# %% [markdown]
# # ACM on diploma, age, gender and category_salary

# %%
test = sub_df.drop(
        [
            
            "annual_salary",
            "industry cluster tf_idf_bigrams",
            "gender",
            "overall_years_of_professional_experience",
            #"years_of_experience_in_field", 
            "country",
            #"highest_level_of_education_completed",
            #"category_salary",
            #"how_old_are_you",
        ],
        axis=1
)

# %%
mca = prince.MCA(n_components=5, n_iter=1000, copy=True, check_input=True, engine='auto',)
pls = mca.fit(test)

# %%
mca.explained_inertia_
# Out:
# [0.08862315312611817,
#  0.07463983129779161,
#  0.06541338135414392,
#  0.061686260333033094,
#  0.057333226191414365]

# %%
mca.plot_coordinates(
    X=test,
    ax=None,
    figsize=(12, 12),
    show_row_points=True,
    row_points_alpha=0.5,
    show_column_labels=True,
    show_column_points=True,
    show_row_labels=False,
    row_points_size=10,
    column_points_size=50,
    legend_n_cols=2,
)
# Out:
# <AxesSubplot:title={'center':'Row and column principal coordinates'}, xlabel='Component 0 (8.86% inertia)', ylabel='Component 1 (7.46% inertia)'>

# %%
def get_differenciation(x):
    if "years_of_experience_in_field_" in x:
        return "Experience"
    elif "highest_level_of_education_completed" in x:
        return "Diploma"
    elif "category_salary" in x:
        return "Salary Category"
    else:
        return "Age"

# %%
transfo = mca.column_coordinates(test).reset_index()
transfo["color"] = transfo["index"].apply(get_differenciation)
transfo["index"] = transfo["index"].str.replace("years_of_experience_in_field_", "")
transfo["index"] = transfo["index"].str.replace("highest_level_of_education_completed_", "")
transfo["index"] = transfo["index"].str.replace("how_old_are_you_", "")
transfo["index"] = transfo["index"].str.replace("category_salary_", "")

# %%
plt.figure(figsize=(10, 10))
ax = sns.scatterplot(data=transfo, x=0, y=1, hue="color", s=200, style="color")
sns.scatterplot(data=mca.row_coordinates(test), x=0, y=1, s=10)
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[0], transfo[1], transfo["index"], plt.gca())  
plt.show()

# %%
sub_df["gender"].value_counts()
# Out:
# Woman                   20115
# Man                      4663
# Non-binary                705
# Prefer not to answer      380
# Name: gender, dtype: int64

# %% [markdown]
# # ACM on diploma, age, gender, years in field and category_salary

# %%
test = sub_df.drop(
        [
            
            "annual_salary",
            "industry cluster tf_idf_bigrams",
            #"gender",
            "overall_years_of_professional_experience",
            #"years_of_experience_in_field", 
            "country",
            #"highest_level_of_education_completed",
            #"category_salary",
            #"how_old_are_you",
        ],
        axis=1
)

# %%
mca = prince.MCA(n_components=5, n_iter=1000, copy=True, check_input=True, engine='auto',)
pls = mca.fit(test)

# %%
mca.explained_inertia_
# Out:
# [0.07947411500384836,
#  0.06541231320783382,
#  0.05763924175667701,
#  0.0540370018168107,
#  0.05035939437754499]

# %%
mca.plot_coordinates(
    X=test,
    ax=None,
    figsize=(12, 12),
    show_row_points=False,
    row_points_alpha=0.5,
    show_column_labels=True,
    show_column_points=True,
    show_row_labels=False,
    row_points_size=10,
    column_points_size=50,
    legend_n_cols=2,
)
# Out:
# <AxesSubplot:title={'center':'Row and column principal coordinates'}, xlabel='Component 0 (7.95% inertia)', ylabel='Component 1 (6.54% inertia)'>

# %%
def get_differenciation(x):
    if "gender_" in x:
        return "Gender"
    elif "highest_level_of_education_completed" in x:
        return "Diploma"
    elif "category_salary" in x:
        return "Salary Category"
    elif "years_of_experience_in_field_" in x:
        return "Experience"
    else:
        return "Age"

# %%
transfo = mca.column_coordinates(test).reset_index()
transfo["color"] = transfo["index"].apply(get_differenciation)
transfo["index"] = transfo["index"].str.replace("gender_", "")
transfo["index"] = transfo["index"].str.replace("highest_level_of_education_completed_", "")
transfo["index"] = transfo["index"].str.replace("how_old_are_you_", "")
transfo["index"] = transfo["index"].str.replace("category_salary_", "")
transfo["index"] = transfo["index"].str.replace("years_of_experience_in_field_", "")

# %%
plt.figure(figsize=(10, 10))
ax = sns.scatterplot(data=transfo, x=0, y=1, hue="color", s=200, style="color")
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[0], transfo[1], transfo["index"], plt.gca())  
plt.show()

# %% [markdown]
# # MCA on gender, age, years in field, industry, diploma and category salary

# %%
test = sub_df.drop(
        [
            
            "annual_salary",
            #"industry cluster tf_idf_bigrams",
            "gender",
            "overall_years_of_professional_experience",
            #"years_of_experience_in_field", 
            "country",
            #"highest_level_of_education_completed",
            #"category_salary",
            #"how_old_are_you",
        ],
        axis=1
)

# %%
mca = prince.MCA(n_components=5, n_iter=1000, copy=True, check_input=True, engine='auto',)
pls = mca.fit(test)

# %%
mca.explained_inertia_
# Out:
# [0.04670329942337663,
#  0.03925348679369667,
#  0.03713297169968601,
#  0.03438686651102217,
#  0.03244615106294044]

# %%
mca.plot_coordinates(
    X=test,
    ax=None,
    figsize=(12, 12),
    show_row_points=False,
    row_points_alpha=0.5,
    show_column_labels=True,
    show_column_points=True,
    show_row_labels=False,
    row_points_size=10,
    column_points_size=50,
    legend_n_cols=2,
)
# Out:
# <AxesSubplot:title={'center':'Row and column principal coordinates'}, xlabel='Component 0 (4.67% inertia)', ylabel='Component 1 (3.93% inertia)'>

# %%
def get_differenciation(x):
    if "years_of_experience_in_field" in x:
        return "Experience"
    elif "highest_level_of_education_completed" in x:
        return "Diploma"
    elif "category_salary" in x:
        return "Salary Category"
    elif "industry cluster tf_idf_bigrams_" in x:
        return "Industry"
    else:
        return "Age"


transfo = mca.column_coordinates(test).reset_index()
transfo["color"] = transfo["index"].apply(get_differenciation)
transfo["index"] = transfo["index"].str.replace("years_of_experience_in_field", "")
transfo["index"] = transfo["index"].str.replace("highest_level_of_education_completed_", "")
transfo["index"] = transfo["index"].str.replace("how_old_are_you_", "")
transfo["index"] = transfo["index"].str.replace("category_salary_", "")
transfo["index"] = transfo["index"].str.replace("industry cluster tf_idf_bigrams_", "")


plt.figure(figsize=(20, 20))
ax = sns.scatterplot(data=transfo, x=1, y=2, hue="color", s=500, style="color")
#sns.scatterplot(data=mca.row_coordinates(test), x=1, y=2, alpha=0.1)
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[1], transfo[2], transfo["index"], plt.gca())  
plt.show()

# %%
sns.scatterplot(data=mca.row_coordinates(test), x=1, y=2)
# Out:
# <AxesSubplot:xlabel='1', ylabel='2'>

# %%
transfo.to_csv("mca_projection.csv")

# %%
mca.row_coordinates(test).to_csv("mca_projection_points.csv")

# %% [markdown]
# # KMeans

# %%
sse={}
for k in np.arange(2,10, 1):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(mca.row_coordinates(test))
    sse[k] = kmeans.inertia_

plt.figure(figsize=(16, 6))
plt.plot(list(sse.keys()),list(sse.values()))
plt.show()

# %%
kmeans = KMeans(n_clusters=3, max_iter=1000).fit(mca.row_coordinates(test))

# %%
result = kmeans.predict(mca.row_coordinates(test))
clusters = mca.row_coordinates(test)
clusters["cluster"] = pd.Categorical(result)
clusters
# Out:
#               0         1         2         3         4 cluster
# 0     -0.361618 -0.251050 -0.527312  0.865335  0.271820       1
# 1     -0.569737  0.013834  0.083198  0.002877 -0.683140       1
# 2     -0.863939  0.256198  0.260321 -0.099704 -0.240124       1
# 3     -0.650471 -0.233506 -0.208439  0.505899 -0.405812       1
# 4     -0.533690 -0.071599 -0.013391  0.237670 -0.554619       1
# ...         ...       ...       ...       ...       ...     ...
# 26227 -0.435265 -0.128229 -0.074482  0.214855 -0.718660       1
# 26228 -0.603608  0.015162 -0.093452 -0.058292  0.261309       1
# 26229  0.499228 -0.268221 -0.215605 -0.222633 -0.394810       0
# 26230 -0.860725 -0.093768  0.013268  0.215979 -0.786040       1
# 26231  0.776204 -1.149733  0.950555  0.160174  0.367083       2
#
# [25863 rows x 6 columns]

# %%
plt.figure(figsize=(20, 20))
ax = sns.scatterplot(data=transfo, x=0, y=1, style="color", s=500)
sns.scatterplot(data=clusters, x=0, y=1, s=100, hue="cluster",alpha=0.2)
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[0], transfo[1], transfo["index"], plt.gca())  
plt.show()

# %%
plt.figure(figsize=(20, 20))
ax = sns.scatterplot(data=transfo, x=1, y=2, style="color", s=500)
sns.scatterplot(data=clusters, x=1, y=2, s=100, alpha=0.2, hue="cluster")
for i in clusters["cluster"].unique():
    points = clusters[clusters["cluster"] == i][[1, 2]].values
    # get convex hull
    hull = ConvexHull(points)
    # get x and y coordinates
    # repeat last point to close the polygon
    x_hull = np.append(points[hull.vertices,0],
                       points[hull.vertices,0][0])
    y_hull = np.append(points[hull.vertices,1],
                       points[hull.vertices,1][0])
    # plot shape
    plt.fill(x_hull, y_hull, alpha=0.3)
    
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[1], transfo[2], transfo["index"], plt.gca())  
plt.show()

# %%
sns.scatterplot(data=clusters, x=0, y=1, s=100, hue="cluster",alpha=0.2)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %% [markdown]
# # Adaptative KMeans

# %%
import numpy as np
import numpy.linalg as linalg
from scipy.spatial.distance import cdist
from sklearn.base import BaseEstimator, ClusterMixin
from sklearn.utils import check_array


class AdaptiveKMeans(ClusterMixin, BaseEstimator):
    def __init__(self, n_clusters=8, n_init=10, tol=1e-4, max_iter=300):
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.tol = tol
        self.max_iter = max_iter

    def fit(self, X):
        X = check_array(X)

        n, p = X.shape
        n_init = self.n_init
        n_clusters = self.n_clusters
        max_iter = self.max_iter
        tol = self.tol

        centers_opt = None
        Vt_opt = None
        partition_opt = None
        d_opt = float("inf")

        for i in range(n_init):
            # Initialisation des centres des classes avec
            # `np.random.choice`
            # <answer>
            centers = np.random.choice(n, size=n_clusters, replace=False)
            centers = X[centers, :]
            # </answer>

            # Initialisation des matrices de variance--covariance
            # brutes et normalisées
            # <answer>
            Vt = [np.eye(p) for i in range(n_clusters)]
            Vt_norm = [np.eye(p) for i in range(n_clusters)]

            # </answer>

            step = tol + 1
            it = 0

            while step > tol and it < max_iter:
                old_centers = centers

                # Calcul d'une nouvelle partition
                dist = np.concatenate(
                    [
                        cdist(c[None, :], X, metric="mahalanobis",
                              VI=linalg.inv(V))
                        for c, V in zip(centers, Vt_norm)
                    ]
                )
                partition = np.argmin(dist, axis=0)

                # Mise à jour des paramètres
                for k in range(n_clusters):
                    # Extraction des individus de class k
                    # <answer>
                    Xk = X[partition == k, :]
                    # </answer>

                    # On évite les groupements dégénérés (trop peu de
                    # points pour inverser la matrice de
                    # variance--covariance empirique)
                    if Xk.shape[0] >= p:
                        # Calcul du k-ième centre
                        # <answer>
                        centers[k, :] = np.mean(Xk, axis=0)
                        # </answer>

                        # Calcul de la k-ième matrice de
                        # variance-covariance normalisée avec `np.cov` et
                        # `linalg.det`
                        # <answer>
                        c = np.cov(Xk, bias=True, rowvar=False)

                        # Régularisation de la matrice de covariance :
                        # on grossit la diagonale pour la rendre
                        # inversible quoi qu'il arrive.
                        c += 1e-5 * np.eye(c.shape[0])

                        Vt[k] = c
                        Vt_norm[k] = (linalg.det(c)) ** (-1 / p) * c
                        # </answer>

                step = ((old_centers - centers) ** 2).sum()
                it += 1

            # Calcul de `d_tot`. On pourra s'inspirer des instructions
            # permettant de calculer `dist` (voir plus haut).
            # <answer>
            d_tot = sum(
                (
                    cdist(
                        c[None, :],
                        X[partition == k, :],
                        metric="mahalanobis",
                        VI=linalg.inv(V),
                    )
                    ** 2
                ).sum()
                for k, (c, V) in enumerate(zip(centers, Vt_norm))
            )
            # </answer>

            # Mise à jour du modèle optimal si besoin
            if d_tot < d_opt:
                centers_opt = centers
                Vt_opt = Vt
                Vt_norm_opt = Vt_norm
                partition_opt = partition
                d_opt = d_tot

        self.labels_ = partition_opt
        self.cluster_centers_ = centers_opt
        self.covars_ = Vt_opt
        self.covars_norm_ = Vt_norm_opt
        self.d_opt = d_opt

# %%
akmeans = AdaptiveKMeans(n_clusters=3)

result = akmeans.fit_predict(mca.row_coordinates(test))
clusters = mca.row_coordinates(test)
clusters["cluster"] = pd.Categorical(result)
clusters
# Out:
#               0         1         2         3         4 cluster
# 0     -0.361618 -0.251050 -0.527312  0.865335  0.271820       2
# 1     -0.569737  0.013834  0.083198  0.002877 -0.683140       2
# 2     -0.863939  0.256198  0.260321 -0.099704 -0.240124       2
# 3     -0.650471 -0.233506 -0.208439  0.505899 -0.405812       2
# 4     -0.533690 -0.071599 -0.013391  0.237670 -0.554619       2
# ...         ...       ...       ...       ...       ...     ...
# 26227 -0.435265 -0.128229 -0.074482  0.214855 -0.718660       2
# 26228 -0.603608  0.015162 -0.093452 -0.058292  0.261309       2
# 26229  0.499228 -0.268221 -0.215605 -0.222633 -0.394810       2
# 26230 -0.860725 -0.093768  0.013268  0.215979 -0.786040       2
# 26231  0.776204 -1.149733  0.950555  0.160174  0.367083       1
#
# [25863 rows x 6 columns]

# %%
plt.figure(figsize=(20, 20))
ax = sns.scatterplot(data=transfo, x=1, y=2, style="color", s=500)
sns.scatterplot(data=clusters, x=1, y=2, s=100, hue="cluster",alpha=0.2)
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[1], transfo[2], transfo["index"], plt.gca())  
plt.show()

# %%
plt.figure(figsize=(20, 20))
ax = sns.scatterplot(data=transfo, x=1, y=2, style="color", s=500)
sns.scatterplot(data=clusters, x=1, y=2, s=100, alpha=0.2, hue="cluster")
for i in clusters["cluster"].unique():
    points = clusters[clusters["cluster"] == i][[1, 2]].values
    # get convex hull
    hull = ConvexHull(points)
    # get x and y coordinates
    # repeat last point to close the polygon
    x_hull = np.append(points[hull.vertices,0],
                       points[hull.vertices,0][0])
    y_hull = np.append(points[hull.vertices,1],
                       points[hull.vertices,1][0])
    # plot shape
    plt.fill(x_hull, y_hull, alpha=0.3)
    
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(transfo[1], transfo[2], transfo["index"], plt.gca())  
plt.show()

# %%
sns.scatterplot(data=clusters, x=0, y=1, s=100, hue="cluster",alpha=0.2)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>
